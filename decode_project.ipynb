# %%
import pandas as pd
import numpy as np

# %%
# Import file and put the contents in an empty list called Total
file = open("Koding.txt", "r")
Total = []
for line in file.readlines():
    print(line)
    Total.append(line)
file.close()
# Out:
# 249 land
#
# 186 sun
#
# 5 too
#
# 6 huge
#
# 177 dont
#
# 139 such
#
# 278 noun
#
# 132 student
#
# 148 brown
#
# 232 complete
#
# 155 play
#
# 244 cook
#
# 269 yard
#
# 260 clock
#
# 212 would
#
# 213 plain
#
# 36 excite
#
# 3 fire
#
# 283 wish
#
# 126 cool
#
# 58 child
#
# 96 past
#
# 164 colony
#
# 182 oil
#
# 276 dog
#
# 142 back
#
# 56 money
#
# 266 kind
#
# 149 open
#
# 18 finger
#
# 29 touch
#
# 220 are
#
# 277 dad
#
# 117 am
#
# 218 modern
#
# 152 meant
#
# 207 ocean
#
# 90 pitch
#
# 62 suit
#
# 47 town
#
# 26 east
#
# 202 over
#
# 129 group
#
# 124 good
#
# 39 kind
#
# 61 down
#
# 87 band
#
# 16 especially
#
# 63 organ
#
# 297 of
#
# 51 fire
#
# 42 out
#
# 99 area
#
# 190 touch
#
# 163 happen
#
# 66 sat
#
# 239 electric
#
# 115 wrote
#
# 300 buy
#
# 146 lot
#
# 30 stop
#
# 194 corn
#
# 31 where
#
# 105 check
#
# 203 live
#
# 138 best
#
# 247 hold
#
# 251 cause
#
# 70 grand
#
# 88 present
#
# 136 indicate
#
# 144 slave
#
# 81 we
#
# 257 like
#
# 13 visit
#
# 168 state
#
# ...

# %%
#Print Total
print(Total)
#length of Total
print(len(Total))
# Out:
# ['249 land\n', '186 sun\n', '5 too\n', '6 huge\n', '177 dont\n', '139 such\n', '278 noun\n', '132 student\n', '148 brown\n', '232 complete\n', '155 play\n', '244 cook\n', '269 yard\n', '260 clock\n', '212 would\n', '213 plain\n', '36 excite\n', '3 fire\n', '283 wish\n', '126 cool\n', '58 child\n', '96 past\n', '164 colony\n', '182 oil\n', '276 dog\n', '142 back\n', '56 money\n', '266 kind\n', '149 open\n', '18 finger\n', '29 touch\n', '220 are\n', '277 dad\n', '117 am\n', '218 modern\n', '152 meant\n', '207 ocean\n', '90 pitch\n', '62 suit\n', '47 town\n', '26 east\n', '202 over\n', '129 group\n', '124 good\n', '39 kind\n', '61 down\n', '87 band\n', '16 especially\n', '63 organ\n', '297 of\n', '51 fire\n', '42 out\n', '99 area\n', '190 touch\n', '163 happen\n', '66 sat\n', '239 electric\n', '115 wrote\n', '300 buy\n', '146 lot\n', '30 stop\n', '194 corn\n', '31 where\n', '105 check\n', '203 live\n', '138 best\n', '247 hold\n', '251 cause\n', '70 grand\n', '88 present\n', '136 indicat
# ...

# %%
#Create a list of the numbers in each string
empty = []
empty2 = []
nums = []
words = []
combo = []
Sol = []
Final = []
def decode (w):
    #Take the input
    Take = input("Do you need a Python script that can create a pyramid out of numbers such that each level has one more number in it than the previous one.")
    #Create a list of the number of words
    for i in range(len(w)):
        empty.append(i)
    #print(empty)
    #print(w)
    #Separate the numbers and the words/Remove the '\n' substring
    for x in range(len(w)):
        w[x].split(" ")
        Nums = int(w[x].split(" ")[0])
        Words = w[x].split(" ")[1].replace('\n','')
        nums.append(Nums)
        words.append(Words)
    #print(nums, words)
    #Reccombine them and then Sort
    for t in range(len(w)):
        T = list((nums[t],words[t]))
        combo.append(T)
    #print(combo)
    def soort(zz):
        return zz[0]
    combo.sort(key=soort)
    #print(combo)
    #Build Pyramid by find the indices of the strings of interest.
    vv = np.arange(2,100)
    fff = 1
    Sol = []
    ii = 2
    Next = lambda ii:ii+1
    while 2 <= ii <= 24:
        ff = fff + ii
        Sol.append(ff)
        ii=Next(ii)
        fff = ff
    #print(Sol)
    Solution = [1] + Sol
    #print(Solution)
    #Print out the results
    for rr in Sol:
        for rrr in empty:
            if rr==combo[rrr][0]:
                print(combo[rrr][1])
    print("This is a Python script that can create a pyramid out of numbers such that each level has one more number in it than the previous one. The code starts by creating a list of the number of words.  After that, the unwanted text is removed.  Following that, the numbers and the words were separated and then, they were recombined and sorted. Lastly, the last block of code finds the last words in each level of the pyramid. ")


out = decode(Total)
print(out)
# Out:
# Do you need a Python script that can create a pyramid out of numbers such that each level has one more number in it than the previous one. y
# fire
# huge
# card
# over
# discuss
# produce
# excite
# speed
# winter
# sat
# bought
# tone
# check
# major
# indicate
# whole
# heavy
# touch
# card
# modern
# jump
# dog
# buy
# This is a Python script that can create a pyramid out of numbers such that each level has one more number in it than the previous one. The code starts by creating a list of the number of words.  After that, the unwanted text is removed.  Following that, the numbers and the words were separated and then, they were recombined and sorted. Lastly, the last block of code finds the last words in each level of the pyramid.
# None
